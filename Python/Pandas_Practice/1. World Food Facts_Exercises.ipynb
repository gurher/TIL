# %% [markdown]
# # Preparation

# %%
! pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-198ac46f-2aad-42c0-a780-7e5673556b7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-198ac46f-2aad-42c0-a780-7e5673556b7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"edwardher","key":"bb98b3fd3989c7a806f83ad15286fcb0"}'}

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# Make directory named kaggle and copy kaggle.json file there.

# %%
! chmod 600 ~/.kaggle/kaggle.json

# Change the permissions of the file.

# %%
! kaggle datasets list 

#- That's all ! You can check if everything's okay by running this command.

# %% [markdown]
# # Load Data

# %%
! kaggle datasets download -d openfoodfacts/world-food-facts
# Out:
# ...
#  97% 105M/109M [00:01<00:00, 93.1MB/s]
# 100% 109M/109M [00:01<00:00, 97.4MB/s]

# %%
! mkdir train
! unzip world-food-facts.zip -d train
# Out:
# mkdir: cannot create directory ‘train’: File exists
# Archive:  world-food-facts.zip
#   inflating: train/en.openfoodfacts.org.products.tsv

# %% [markdown]
# # 연습 1

# %% [markdown]
# ### 단계 1. https://www.kaggle.com/openfoodfacts/world-food-facts/data 로 간다.

# %% [markdown]
# ### 단계 2.데이터를 다운 받아서 압축을 푼다.

# %% [markdown]
# ### 단계 3. tsv파일을 불러와서 food라는 이름의 데이터 프레임에 저장한다.
# (잊지 말고 넘파이와 판다스를 import한다. 아마 몇 컬럼의 타입이 섞여 있다have mixed types.라는 오류가 뜰 텐데 정상이다. 계속 진행하면 된다.)

# %%
import pandas as pd
import numpy as np

food = pd.read_csv('/content/train/en.openfoodfacts.org.products.tsv', sep='\t')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### 단계 4. 처음 5개 열을 본다

# %%
food.head(5)
# Out:
#     code  ... water-hardness_100g
# 0   3087  ...                 NaN
# 1   4530  ...                 NaN
# 2   4559  ...                 NaN
# 3  16087  ...                 NaN
# 4  16094  ...                 NaN
#
# [5 rows x 163 columns]

# %% [markdown]
# ### 단계 5. 데이터 셋에 있는 관측치는 모두 몇 개인가?

# %%
len(food.columns)
nrow = food.shape[0]
nrow
# Out:
# 356027

# %% [markdown]
# ### 단계 6. 데이터 셋에 있는 열의 수는 몇 개인가?

# %%
ncol = food.shape[1]
ncol
len(food.columns)
# Out:
# 163

# %% [markdown]
# ### 단계 7. 모든 열의 이름을 출력해본다

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# ### 단계 8. 105번째 열의 이름name은 무엇인가?

# %%
food.columns[104]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### 단계 9. 105번째 열의 타입은 무엇인가?

# %%
food['-glucose_100g'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### 단계 10. 데이터는 어떻게 색인 되어 있는가?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# ### 단계 11. 19번째 관측치(observation)의 상품명(product name)은 무엇인가?

# %%
food.loc[18,'product_name']
# Out:
# 'Lotus Organic Brown Jasmine Rice'
